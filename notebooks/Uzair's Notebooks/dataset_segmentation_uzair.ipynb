# %%
import pandas as pd
import matplotlib.pyplot as plt

'''AMAZON Prime Data'''

prime_df = pd.read_csv(r'C:\Users\data science\Downloads\GitHub_Repositories\OTT_SUGGESTER\data\raw\raw_amazon_prime.csv')



# Create empty Datafames for Prime_movies and Prime_series
# prime_movies_df = pd.DataFrame(columns=prime_df.columns)
# prime_series_df = pd.DataFrame(columns=prime_df.columns)

# for index, row in prime_df.iterrows():
#     if row['type'] == 'Movie':
#         # df_row = pd.concat([df_row,row])
#         prime_movies_df = pd.concat([prime_movies_df, row])
#     elif row['type'] == 'TV Show':
#         prime_series_df = pd.concat([prime_series_df, row])

# Separate DatFrame based on the value of column 'type' 
prime_movies_df = prime_df[prime_df['type'] == 'Movie']
prime_series_df = prime_df[prime_df['type'] == 'TV Show']


prime_movies_df['Platform'] = 'prime'
prime_series_df['Platform'] = 'prime'       

# Write obtaied separated data frame to csv
#prime_movies_df.to_csv(r'C:\Users\data science\Downloads\GitHub_Repositories\OTT_SUGGESTER\data\raw\raw_prime_movies.csv')
#prime_series_df.to_csv(r'C:\Users\data science\Downloads\GitHub_Repositories\OTT_SUGGESTER\data\raw\raw_prime_series.csv')

prime_df
# Out:
# C:\Users\data science\AppData\Local\Temp\ipykernel_18424\1486274072.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prime_movies_df['Platform'] = 'prime'
# C:\Users\data science\AppData\Local\Temp\ipykernel_18424\1486274072.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prime_series_df['Platform'] = 'prime'
#          type                    title         director  \
# 0       Movie      The Grand Seduction     Don McKellar
# 1       Movie     Take Care Good Night     Girish Joshi
# 2       Movie     Secrets of Deception      Josh Webber
# 3       Movie       Pink: Staying True   Sonia Anderson
# 4       Movie            Monster Maker     Giles Foster
# ...       ...                      ...              ...
# 9663    Movie      Pride Of The Bowery  Joseph H. Lewis
# 9664  TV Show            Planet Patrol              NaN
# 9665    Movie                  Outpost     Steve Barker
# 9666  TV Show  Maradona: Blessed Dream              NaN
# 9667    Movie              Harry Brown    Daniel Barber
#
#                                                    cast         country  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1      Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2     Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3     Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4     Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
# ...                                                 ...             ...
# 9663                           Leo Gorcey, Bobby Jordan             NaN
# 9664  DICK VOSBURGH, RONNIE STEVENS, LIBBY MORRIS, M...             NaN
# 9665  Ray Stevenson, Julian Wadham, Richard Brake, M...             NaN
# 9666  Esteban Recagno, Ezequiel Stremiz, Luciano Vit...             NaN
# 9667  Michael Caine, Emily Mortimer, Joseph Gilgun, ...             NaN
#
#           date_added  release_year rating   duration                listed_in  \
# 0     March 30, 2021          2014    NaN    113 min            Comedy, Drama
# 1     March 30, 2021          2018    13+    110 min     Drama, International
# 2     March 30, 2021          2017    NaN     74 min  Action, Drama, Suspense
# 3     March 30, 2021          2014    NaN     69 min              Documentary
# 4     March 30, 2021          1989    NaN     45 min           Drama, Fantasy
# ...              ...           ...    ...        ...                      ...
# 9663             NaN          1940     7+     60 min                   Comedy
# 9664             NaN          2018    13+  4 Seasons                 TV Shows
# 9665             NaN          2008      R     90 min                   Action
# 9666             NaN          2021  TV-MA   1 Season            Drama, Sports
# 9667             NaN          2010      R    103 min  Action, Drama, Suspense
#
#                                             description
# 0     A small fishing village must procure a local d...
# 1     A Metro Family decides to fight a Cyber Crimin...
# 2     After a man discovers his wife is cheating on ...
# 3     Pink breaks the mold once again, bringing her ...
# 4     Teenage Matt Banting wants to work with a famo...
# ...                                                 ...
# 9663  New York City street principles get an East Si...
# 9664  This is Earth, 2100AD - and these are the adve...
# 9665  In war-torn Eastern Europe, a world-weary grou...
# 9666  The series tells the story of Diego Maradona, ...
# 9667  Harry Brown, starring two-time Academy Award w...
#
# [9668 rows x 11 columns]

# %%
'''Disney'''

import pandas as pd
disney_df = pd.read_csv(r'C:\Users\data science\Downloads\GitHub_Repositories\OTT_SUGGESTER\data\raw\raw_disney_plus.csv')

# Create empty Datafames for disney_movies and disney_series
disney_movies_df = pd.DataFrame(columns=disney_df.columns)
disney_series_df = pd.DataFrame(columns=disney_df.columns)

# Separate DatFrame based on the value of column 'type' 
disney_movies_df = disney_df[disney_df['type'] == 'Movie']
disney_series_df = disney_df[disney_df['type'] == 'TV Show']

disney_movies_df

# disney_movies_df['Platform'] = 'Disney+'
# disney_series_df['Platform'] = 'Disney+'
# Out:
#      show_id   type                                             title  \
# 0         s1  Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1         s2  Movie                            Ernest Saves Christmas
# 2         s3  Movie                      Ice Age: A Mammoth Christmas
# 3         s4  Movie                        The Queen Family Singalong
# 5         s6  Movie                                 Becoming Cousteau
# ...      ...    ...                                               ...
# 1445   s1446  Movie                          X-Men Origins: Wolverine
# 1446   s1447  Movie    Night at the Museum: Battle of the Smithsonian
# 1447   s1448  Movie                                   Eddie the Eagle
# 1448   s1449  Movie                              Bend It Like Beckham
# 1449   s1450  Movie             Captain Sparky vs. The Flying Saucers
#
#                                director  \
# 0     Alonso Ramirez Ramos, Dave Wasson
# 1                           John Cherry
# 2                          Karen Disher
# 3                       Hamish Hamilton
# 5                            Liz Garbus
# ...                                 ...
# 1445                         Gavin Hood
# 1446                         Shawn Levy
# 1447                    Dexter Fletcher
# 1448                    Gurinder Chadha
# 1449                        Mark Waring
#
#                                                    cast  \
# 0     Chris Diamantopoulos, Tony Anselmo, Tress MacN...
# 1              Jim Varney, Noelle Parker, Douglas Seale
# 2     Raymond Albert Romano, John Leguizamo, Denis L...
# 3     Darren Criss, Adam Lambert, Derek Hough, Alexa...
# 5                 Jacques Yves Cousteau, Vincent Cassel
# ...                                                 ...
# 1445  Hugh Jackman, Liev Schreiber, Danny Huston, wi...
# 1446  Ben Stiller, Amy Adams, Owen Wilson, Hank Azar...
# 1447  Tom Costello, Jo Hartley, Keith Allen, Dickon ...
# 1448  Parminder Nagra, Keira Knightley, Jonathan Rhy...
# 1449                                      Charlie Tahan
#
#                                      country          date_added  \
# 0                                        NaN   November 26, 2021
# 1                                        NaN   November 26, 2021
# 2                              United States   November 26, 2021
# 3                                        NaN   November 26, 2021
# 5                              United States   November 24, 2021
# ...                                      ...                 ...
# 1445           United States, United Kingdom        June 4, 2021
# 1446                   United States, Canada       April 2, 2021
# 1447  United Kingdom, Germany, United States   December 18, 2020
# 1448  United Kingdom, Germany, United States  September 18, 2020
# 1449                           United States       April 1, 2020
#
#       release_year rating duration  \
# 0             2016   TV-G   23 min
# 1             1988     PG   91 min
# 2             2011   TV-G   23 min
# 3             2021  TV-PG   41 min
# 5             2021  PG-13   94 min
# ...            ...    ...      ...
# 1445          2009  PG-13  108 min
# 1446          2009     PG  106 min
# 1447          2016  PG-13  107 min
# 1448          2003  PG-13  112 min
# 1449          2012   TV-G    2 min
#
#                                           listed_in  \
# 0                                 Animation, Family
# 1                                            Comedy
# 2                         Animation, Comedy, Family
# 3                                           Musical
# 5                         Biographical, Documentary
# ...                                             ...
# 1445      Action-Adventure, Family, Science Fiction
# 1446               Action-Adventure, Comedy, Family
# 1447                    Biographical, Comedy, Drama
# 1448                   Buddy, Comedy, Coming of Age
# 1449  Action-Adventure, Animals & Nature, Animation
#
#                                             description
# 0      Join Mickey and the gang as they duck the halls!
# 1     Santa Claus passes his magic bag to a new St. ...
# 2             Sid the Sloth is on Santa's naughty list.
# 3                  This is real life, not just fantasy!
# 5     An inside look at the legendary life of advent...
# ...                                                 ...
# 1445  Wolverine unites with legendary X-Men to fight...
# 1446  Larry Daley returns to rescue some old friends...
# 1447  True story of Eddie Edwards, a British ski-jum...
# 1448  Despite the wishes of their traditional famili...
# 1449         View one of Sparky's favorite home movies.
#
# [1052 rows x 12 columns]

# %%
'''Netflix'''

import pandas as pd
netflix_df = pd.read_csv(r'C:\Users\data science\Downloads\GitHub_Repositories\OTT_SUGGESTER\data\raw\raw_netflix.csv')

# Create empty Datafames for netflix_movies and netflix_series
netflix_movies_df = pd.DataFrame(columns=netflix_df.columns)
netflix_series_df = pd.DataFrame(columns=netflix_df.columns)

# Separate DatFrame based on the value of column 'type' 
netflix_movies_df = netflix_df[netflix_df['type'] == 'Movie']
netflix_series_df = netflix_df[netflix_df['type'] == 'TV Show']

# %%
'''Data Merging'''
import pandas as pd

raw_prime_movies = pd.read_csv(r'C:\Users\data science\Downloads\GitHub_Repositories\OTT_SUGGESTER\data\raw\raw_prime_movies.csv')
raw_prime_series = pd.read_csv(r'C:\Users\data science\Downloads\GitHub_Repositories\OTT_SUGGESTER\data\raw\raw_prime_series.csv')

raw_netflix_movies = pd.read_csv(r'C:\Users\data science\Downloads\GitHub_Repositories\OTT_SUGGESTER\data\raw\raw_netflix_movies.csv')
raw_netflix_series = pd.read_csv(r'C:\Users\data science\Downloads\GitHub_Repositories\OTT_SUGGESTER\data\raw\raw_netflix_series.csv')

raw_disney_movies = pd.read_csv(r'C:\Users\data science\Downloads\GitHub_Repositories\OTT_SUGGESTER\data\raw\raw_disney_movies.csv')
raw_disney_series = pd.read_csv(r'C:\Users\data science\Downloads\GitHub_Repositories\OTT_SUGGESTER\data\raw\raw_disney_series.csv')

raw_combined_movies = pd.concat([raw_prime_movies, raw_netflix_movies, raw_disney_movies], ignore_index= True) 

raw_combined_series = pd.concat([raw_prime_series, raw_netflix_series, raw_disney_series], ignore_index= True)

mapping = {'Prime Video': 'prime_video', 'Netflix': 'netflix', 'Disney+': 'disney+'}
raw_combined_movies['Platform'] = raw_combined_movies['Platform'].replace(mapping)
raw_combined_series['Platform'] = raw_combined_series['Platform'].replace(mapping)

# Writing to CSV file 

#aw_combined_movies.to_csv(r'C:\Users\data science\Downloads\GitHub_Repositories\OTT_SUGGESTER\data\raw\raw_combined_movies.csv')
#raw_combined_series.to_csv(r'C:\Users\data science\Downloads\GitHub_Repositories\OTT_SUGGESTER\data\raw\raw_combined_series.csv')

# %%
import pandas as pd

combined_df = pd.read_csv(r'C:\Users\data science\Downloads\GitHub_Repositories\OTT_SUGGESTER\data\raw\raw_combined_movies.csv')

combined_df
# Out:
#       show_id   type                                           title  \
# 0          s1  Movie                            Dick Johnson Is Dead
# 1          s7  Movie                My Little Pony: A New Generation
# 2          s8  Movie                                         Sankofa
# 3         s10  Movie                                    The Starling
# 4         s13  Movie                                    Je Suis Karl
# ...       ...    ...                                             ...
# 14992   s1446  Movie                        X-Men Origins: Wolverine
# 14993   s1447  Movie  Night at the Museum: Battle of the Smithsonian
# 14994   s1448  Movie                                 Eddie the Eagle
# 14995   s1449  Movie                            Bend It Like Beckham
# 14996   s1450  Movie           Captain Sparky vs. The Flying Saucers
#
#                             director  \
# 0                    Kirsten Johnson
# 1      Robert Cullen, José Luis Ucha
# 2                       Haile Gerima
# 3                     Theodore Melfi
# 4                Christian Schwochow
# ...                              ...
# 14992                     Gavin Hood
# 14993                     Shawn Levy
# 14994                Dexter Fletcher
# 14995                Gurinder Chadha
# 14996                    Mark Waring
#
#                                                     cast  \
# 0                                                    NaN
# 1      Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 2      Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 3      Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 4      Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# ...                                                  ...
# 14992  Hugh Jackman, Liev Schreiber, Danny Huston, wi...
# 14993  Ben Stiller, Amy Adams, Owen Wilson, Hank Azar...
# 14994  Tom Costello, Jo Hartley, Keith Allen, Dickon ...
# 14995  Parminder Nagra, Keira Knightley, Jonathan Rhy...
# 14996                                      Charlie Tahan
#
#                                                  country          date_added  \
# 0                                          United States  September 25, 2021
# 1                                                    NaN  September 24, 2021
# 2      United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 3                                          United States  September 24, 2021
# 4                                Germany, Czech Republic  September 23, 2021
# ...                                                  ...                 ...
# 14992                      United States, United Kingdom        June 4, 2021
# 14993                              United States, Canada       April 2, 2021
# 14994             United Kingdom, Germany, United States   December 18, 2020
# 14995             United Kingdom, Germany, United States  September 18, 2020
# 14996                                      United States       April 1, 2020
#
#        release_year rating duration  \
# 0              2020  PG-13   90 min
# 1              2021     PG   91 min
# 2              1993  TV-MA  125 min
# 3              2021  PG-13  104 min
# 4              2021  TV-MA  127 min
# ...             ...    ...      ...
# 14992          2009  PG-13  108 min
# 14993          2009     PG  106 min
# 14994          2016  PG-13  107 min
# 14995          2003  PG-13  112 min
# 14996          2012   TV-G    2 min
#
#                                               listed_in  \
# 0                                         Documentaries
# 1                              Children & Family Movies
# 2      Dramas, Independent Movies, International Movies
# 3                                      Comedies, Dramas
# 4                          Dramas, International Movies
# ...                                                 ...
# 14992         Action-Adventure, Family, Science Fiction
# 14993                  Action-Adventure, Comedy, Family
# 14994                       Biographical, Comedy, Drama
# 14995                      Buddy, Comedy, Coming of Age
# 14996     Action-Adventure, Animals & Nature, Animation
#
#                                              description Platform
# 0      As her father nears the end of his life, filmm...  Netflix
# 1      Equestria's divided. But a bright-eyed hero be...  Netflix
# 2      On a photo shoot in Ghana, an American model s...  Netflix
# 3      A woman adjusting to life after a loss contend...  Netflix
# 4      After most of her family is murdered in a terr...  Netflix
# ...                                                  ...      ...
# 14992  Wolverine unites with legendary X-Men to fight...  Disney+
# 14993  Larry Daley returns to rescue some old friends...  Disney+
# 14994  True story of Eddie Edwards, a British ski-jum...  Disney+
# 14995  Despite the wishes of their traditional famili...  Disney+
# 14996         View one of Sparky's favorite home movies.  Disney+
#
# [14997 rows x 13 columns]
